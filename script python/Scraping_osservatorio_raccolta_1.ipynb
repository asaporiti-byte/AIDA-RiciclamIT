# %% [markdown]
# installazione Chrome

# %%
# %%shell
# sudo apt -y update
# sudo apt install -y wget curl unzip
#
# wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# dpkg -i libu2f-udev_1.1.4-1_all.deb
#
# wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
#
# dpkg -i google-chrome-stable_current_amd64.deb
#
# sudo apt-get install -f
# Out:
# Get:1 https://dl.google.com/linux/chrome-stable/deb stable InRelease [1,825 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 https://dl.google.com/linux/chrome-stable/deb stable/main amd64 Packages [1,218 B]
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,043 B in 1s (3,492 B/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 89 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...

# %%
# !google-chrome --version
# Out:
# Google Chrome 150.0.7871.114

# %% [markdown]
# installa Selenium

# %%
# !pip install -U selenium

# %%
# !pip install chromedriver-py==150.0.7871.115
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 MB 26.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chromedriver-py
#     Found existing installation: chromedriver-py 148.0.7778.178
#     Uninstalling chromedriver-py-148.0.7778.178:
#       Successfully uninstalled chromedriver-py-148.0.7778.178
# ...

# %%
import sys
import logging

from selenium.webdriver.remote.remote_connection import LOGGER

LOGGER.setLevel(logging.WARNING)

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

from tqdm.notebook import tqdm

import pandas as pd
import json
import pprint

from chromedriver_py import binary_path

# %% [markdown]
# configurazione

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.binary_location = "/opt/google/chrome/chrome"
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument(
    "window-size=1900,800"
)
chrome_options.add_argument(
    "user-agent=Mozilla/5.0"
)

# %% [markdown]
# avvio selenium

# %%
service = Service(
    executable_path=binary_path
)

wd = webdriver.Chrome(
    service=service,
    options=chrome_options
)

# %% [markdown]
# apertura sito

# %%
wd.get(
    "https://osservatorioraccoltadifferenziata.it/dati-raccolta-urbana/"
)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     570         # Get the response from http.client.HTTPConnection
# --> 571         httplib_response = super().getresponse()
#     572
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1449             try:
# -> 1450                 response.begin()
#    1451             except ConnectionError:
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     335         while True:
# ...

# %%
pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 37.0 MB/s eta 0:00:00
# ...

# %%
import psycopg2

conn_string = "postgresql://postgres.ctmmjdarazuylihuslmm:ryzen_2026_2026@aws-0-<regione>.pooler.supabase.com:6543/postgres"

try:
    conn = psycopg2.connect(conn_string)
    cursor = conn.cursor()

    cursor.execute("SELECT * FROM test;")
    rows = cursor.fetchall()

    colnames = [desc[0] for desc in cursor.description]
    print(colnames)

    for row in rows:
        print(row)

except Exception as e:
    print("Errore durante la connessione o la query:", e)

finally:
    if 'cursor' in locals():
        cursor.close()
    if 'conn' in locals():
        conn.close()
# Out:
# Errore durante la connessione o la query: could not translate host name "aws-0-<regione>.pooler.supabase.com" to address: Name or service not known
